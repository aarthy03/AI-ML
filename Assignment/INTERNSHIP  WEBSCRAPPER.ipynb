# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://internshala.com/internships"

# %%
website_allow=requests.get(url)

# %%
website_allow
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(website_allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
# <meta content="702141670710132" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="@Internshala" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@internshala" name="twitter:creator"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="#ffffff" name="msapplication-navbutton-color"/>
# <meta content="telephone=no" name="format-detection"/>
# <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" rel="preload" type="font/woff2"/>
# ...

# %%
c=soup.select(".link_display_like_text")

# %%
c
# Out:
# [<a class="link_display_like_text" href="/internships/internship-at-Childo%20Education%20Research%20And%20Development%20Foundation">
#                          Childo Education Research And Development Foundation                    </a>,
#  <a class="link_display_like_text" href="/internships/internship-at-Jankalyan%20Multipurpose%20Education%20Society">
#                          Jankalyan Multipurpose Education Society                    </a>,
#  <a class="link_display_like_text" href="/internships/internship-at-Pledge%20A%20Smile%20Foundation">
#                          Pledge A Smile Foundation                    </a>,
#  <a class="link_display_like_text" href="/internships/internship-at-Tare%20Zameen%20Foundation">
#                          Tare Zameen Foundation                    </a>,
#  <a class="link_display_like_text" href="/internships/internship-at-Internshala">
#                          Internshala                    </a>,
# ...

# %%
c1=[]

# %%
for i in c:
    c1.append(i.text)

# %%
c1
# Out:
# ['\n                        Childo Education Research And Development Foundation                    ',
#  '\n                        Jankalyan Multipurpose Education Society                    ',
#  '\n                        Pledge A Smile Foundation                    ',
#  '\n                        Tare Zameen Foundation                    ',
#  '\n                        Internshala                    ',
#  '\n                        Justdial Limited                    ',
#  "\n                        BYJU'S The Learning App                    ",
#  '\n                        HCL Technologies                    ',
#  '\n                        Taylor & Francis India                    ',
#  "\n                        Think & Learn Private Limited (BYJU'S)                    ",
#  "\n                        Think & Learn Private Limited (BYJU'S)                    ",
#  '\n                        United Nations Volunteer                    ',
# ...

# %%
loc=soup.select(".location_link")

# %%
loc
# Out:
# [<a class="location_link" href="/internships/virtual-internship">Work From Home</a>,
#  <a class="location_link" href="/internships/virtual-internship">Work From Home</a>,
#  <a class="location_link" href="/internships/virtual-internship">Work From Home</a>,
#  <a class="location_link" href="/internships/virtual-internship">Work From Home</a>,
#  <a class="location_link" href="/internships/internship-in-gurgaon">Gurgaon</a>,
#  <a class="location_link" href="/internships/internship-in-chennai">Chennai</a>,
#  <a class="location_link" href="/internships/internship-in-margao">Margao</a>,
#  <a class="location_link" href="/internships/internship-in-panjim">Panjim</a>,
#  <a class="location_link" href="/internships/internship-in-vasco da gama">Vasco Da Gama</a>,
#  <a class="location_link" href="/internships/internship-in-ponda">Ponda</a>,
#  <a class="location_link" href="/internships/internship-in-mapusa">Mapusa</a>,
# ...

# %%
l=[]

# %%
for j in loc:
    l.append(j.text)

# %%
l
# Out:
# ['Work From Home',
#  'Work From Home',
#  'Work From Home',
#  'Work From Home',
#  'Gurgaon',
#  'Chennai',
#  'Margao',
#  'Panjim',
#  'Vasco Da Gama',
#  'Ponda',
#  'Mapusa',
#  'Bicholim',
#  'Delhi',
#  'Noida',
#  'Delhi',
#  'Hyderabad',
#  'Gandhidham',
#  'Work From Home',
#  'Delhi',
#  'Ghaziabad',
#  'Gurgaon',
#  'Noida',
#  'Aurangabad',
#  'Jalna',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Kollam',
#  'Kottayam',
#  'Kozhikode',
#  'Pathanamthitta',
#  'Thiruvananthapuram',
#  'Thrissur',
#  'Malappuram',
#  'Kasaragod',
#  'Wayanad',
#  'Idukki',
#  'Ernakulam',
#  'Kannur',
#  'Mumbai',
#  'Mumbai',
#  'Work From Home',
#  'Mumbai',
#  'Mumbai',
#  'Pune',
#  'Bhubaneswar',
#  'Vadodara',
#  'Raipur',
#  'Delhi',
#  'Gurgaon',
#  'Bangalore',
#  'Mumbai',
#  'Work From Home',
#  'Work From Home',
#  'Nagapattinam',
#  'Thoothukudi',
#  'Kanyakumari',
#  'Krishnagiri',
#  'Namakkal',
#  'Tirupattur',
#  'Tiruppur',
#  'Ranipet',
#  'Tiruchirappalli',
# ...

# %%
s=soup.select(".stipend")

# %%
s
# Out:
# [<span class="stipend">Unpaid</span>,
#  <span class="stipend">Unpaid</span>,
#  <span class="stipend">Unpaid</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 1000 /month +  Incentives</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 20000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 5000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 20000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 5000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 12000-20000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 15000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 18000 /month</span>,
#  <span class="stipend">Unpaid</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 10000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 5000 /month +  Incentives</span>,
# ...

# %%
s1=[]

# %%
for k in s:
    s1.append(k.text)

# %%
s1
# Out:
# ['Unpaid',
#  'Unpaid',
#  'Unpaid',
#  ' 1000 /month +  Incentives',
#  ' 20000 /month',
#  ' 5000 /month',
#  ' 20000 /month',
#  ' 5000 /month',
#  ' 12000-20000 /month',
#  ' 15000 /month',
#  ' 18000 /month',
#  'Unpaid',
#  ' 10000 /month',
#  ' 5000 /month +  Incentives',
#  ' 8000 /month',
#  ' 5000-8000 /month',
#  ' 5000 /month',
#  ' 18000 /month',
#  ' 7500 /month',
#  ' 10000 /month',
#  ' 3000-5000 /month',
#  ' 15000-22000 /month',
#  ' 5000 /month',
#  ' 5000 /month',
#  ' 15000 /month',
#  ' 12000 /month',
#  ' 15000 /month',
#  ' 15000 /month',
#  ' 25000 /month',
#  ' 20000 /month',
#  ' 7000 /month',
#  ' 16000 /month',
#  ' 7000 /month',
#  ' 2000-4000 /month',
#  ' 18000 /month',
#  ' 20000 /month',
#  ' 20000 /month',
#  ' 20000 /month',
#  ' 8000 /month',
#  ' 20000 /month']

# %%
sd=soup.select(".start_immediately_desktop")

# %%
sd
# Out:
# [<span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
#  <span class="start_immediately_desktop">Immediately</span>,
# ...

# %%
sd1=[]

# %%
for n in sd:
    sd1.append(n.text)

# %%
sd1
# Out:
# ['Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately',
#  'Immediately']

# %%
d=soup.select(".other_detail_item_row:nth-child(1) .other_detail_item+ .other_detail_item .item_body")

# %%
d
# Out:
# [<div class="item_body">
#                              2 Weeks                        </div>,
#  <div class="item_body">
#                              1 Week                        </div>,
#  <div class="item_body">
#                              1 Month                        </div>,
#  <div class="item_body">
#                              1 Month                        </div>,
#  <div class="item_body">
#                              6 Months                        </div>,
#  <div class="item_body">
#                              2 Months                        </div>,
#  <div class="item_body">
#                              2 Months                        </div>,
#  <div class="item_body">
#                              3 Months                        </div>,
#  <div class="item_body">
#                              6 Months                        </div>,
#  <div class="item_body">
#                              3 Months                        </div>,
# ...

# %%
d1=[]

# %%
for m in d:
    d1.append(m.text)

# %%
d1
# Out:
# ['\n                            2 Weeks                        ',
#  '\n                            1 Week                        ',
#  '\n                            1 Month                        ',
#  '\n                            1 Month                        ',
#  '\n                            6 Months                        ',
#  '\n                            2 Months                        ',
#  '\n                            2 Months                        ',
#  '\n                            3 Months                        ',
#  '\n                            6 Months                        ',
#  '\n                            3 Months                        ',
#  '\n                            2 Months                        ',
#  '\n                            3 Weeks                        ',
#  '\n                            6 Months                        ',
#  '\n                            2 Months                        ',
# ...

# %%
a=soup.select(".apply_by .item_body")

# %%
a
# Out:
# [<div class="item_body">23 May' 22</div>,
#  <div class="item_body">31 May' 22</div>,
#  <div class="item_body">19 May' 22</div>,
#  <div class="item_body">20 May' 22</div>,
#  <div class="item_body">20 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">25 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
#  <div class="item_body">25 May' 22</div>,
#  <div class="item_body">26 May' 22</div>,
# ...

# %%
a1=[]

# %%
for o in a:
    a1.append(o.text)

# %%
a1
# Out:
# ["23 May' 22",
#  "31 May' 22",
#  "19 May' 22",
#  "20 May' 22",
#  "20 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "26 May' 22",
#  "25 May' 22",
#  "26 May' 22",
#  "25 May' 22",
#  "26 May' 22",
#  "25 May' 22",
#  "25 May' 22",
#  "26 May' 22",
#  "25 May' 22",
#  "25 May' 22",
#  "24 May' 22",
#  "24 May' 22",
#  "24 May' 22",
#  "25 May' 22",
#  "24 May' 22",
#  "25 May' 22",
#  "24 May' 22",
#  "24 May' 22",
#  "25 May' 22",
#  "25 May' 22",
#  "25 May' 22",
#  "25 May' 22",
#  "25 May' 22"]

# %%
c2=soup.select(".profile a")

# %%
c2
# Out:
# [<a href="/internship/detail/fundraising-work-from-home-job-internship-at-childo-education-research-and-development-foundation1651906098">Fundraising</a>,
#  <a href="/internship/detail/fundraising-work-from-home-job-internship-at-jankalyan-multipurpose-education-society1651752498">Fundraising</a>,
#  <a href="/internship/detail/fundraising-work-from-home-job-internship-at-pledge-a-smile-foundation1651757476">Fundraising</a>,
#  <a href="/internship/detail/fundraising-work-from-home-job-internship-at-tare-zameen-foundation1651821753">Fundraising</a>,
#  <a href="/internship/detail/community-management-internship-in-gurgaon-at-internshala1651838324">Community Management</a>,
#  <a href="/internship/detail/human-resources-hr-internship-in-chennai-at-justdial-limited1652185175">Human Resources (HR)</a>,
#  <a href="/internship/detail/marketing-internship-in-multiple-locations-at-byjus-the-learning-app1652361200">Marketing</a>,
# ...

# %%
c3=[]

# %%
for p in c2:
    c3.append(p.text)

# %%
c3
# Out:
# ['Fundraising',
#  'Fundraising',
#  'Fundraising',
#  'Fundraising',
#  'Community Management',
#  'Human Resources (HR)',
#  'Marketing',
#  'Marketing',
#  'Market Research',
#  'Business Development (Field Marketing)',
#  'Marketing',
#  'Volunteering - World Environment Day 2022',
#  'Digital Marketing',
#  'Business Development (Sales)',
#  'Graphic Design',
#  'Video Making/Editing',
#  'Project Management',
#  'Marketing',
#  'Graphic Design',
#  'Human Resources (HR)',
#  'Text Correction (Sanskrit)',
#  'Business Development (Sales)',
#  'Content QC (Music)',
#  'Omni Sports Leadership (Watersports)',
#  'Business Development (Sales)',
#  'Product Design',
#  'Fundraising',
#  'Business Development (Sales)',
#  'Content Writing',
#  'Marketing',
#  'Public Policy',
#  'Marketing',
#  'Event Management',
#  'Business Development (Sales)',
#  'Marketing',
#  'Marketing',
#  'Marketing',
#  'Marketing',
#  'Fashion Design',
#  'Marketing']

# %%
import pandas as pd

# %%
df=pd.DataFrame(c,columns=["COMPANY_NAME"])

# %%
df
# Out:
#                                          COMPANY_NAME
# 0   \n                        Childo Education Res...
# 1   \n                        Jankalyan Multipurpo...
# 2   \n                        Pledge A Smile Found...
# 3   \n                        Tare Zameen Foundati...
# 4   \n                        Internshala         ...
# 5   \n                        Justdial Limited    ...
# 6   \n                        BYJU'S The Learning ...
# 7   \n                        HCL Technologies    ...
# 8   \n                        Taylor & Francis Ind...
# 9   \n                        Think & Learn Privat...
# 10  \n                        Think & Learn Privat...
# 11  \n                        United Nations Volun...
# 12  \n                        Times Internet      ...
# 13  \n                        LIC Of India        ...
# 14  \n                        Bewakoof            ...
# 15  \n                        Aditya Birla Fashion...
# ...

# %%
df["CATEGORY"]=c3

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0   \n                        Childo Education Res...
# 1   \n                        Jankalyan Multipurpo...
# 2   \n                        Pledge A Smile Found...
# 3   \n                        Tare Zameen Foundati...
# 4   \n                        Internshala         ...
# 5   \n                        Justdial Limited    ...
# 6   \n                        BYJU'S The Learning ...
# 7   \n                        HCL Technologies    ...
# 8   \n                        Taylor & Francis Ind...
# 9   \n                        Think & Learn Privat...
# 10  \n                        Think & Learn Privat...
# 11  \n                        United Nations Volun...
# 12  \n                        Times Internet      ...
# 13  \n                        LIC Of India        ...
# 14  \n                        Bewakoof            ...
# 15  \n                        Aditya Birla Fashion...
# ...

# %%
df["DURATION_IN_MONTHS"]=d1

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0   \n                        Childo Education Res...
# 1   \n                        Jankalyan Multipurpo...
# 2   \n                        Pledge A Smile Found...
# 3   \n                        Tare Zameen Foundati...
# 4   \n                        Internshala         ...
# 5   \n                        Justdial Limited    ...
# 6   \n                        BYJU'S The Learning ...
# 7   \n                        HCL Technologies    ...
# 8   \n                        Taylor & Francis Ind...
# 9   \n                        Think & Learn Privat...
# 10  \n                        Think & Learn Privat...
# 11  \n                        United Nations Volun...
# 12  \n                        Times Internet      ...
# 13  \n                        LIC Of India        ...
# 14  \n                        Bewakoof            ...
# 15  \n                        Aditya Birla Fashion...
# ...

# %%
df["STIPEND_PER_MONTH"]=s1

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0   \n                        Childo Education Res...
# 1   \n                        Jankalyan Multipurpo...
# 2   \n                        Pledge A Smile Found...
# 3   \n                        Tare Zameen Foundati...
# 4   \n                        Internshala         ...
# 5   \n                        Justdial Limited    ...
# 6   \n                        BYJU'S The Learning ...
# 7   \n                        HCL Technologies    ...
# 8   \n                        Taylor & Francis Ind...
# 9   \n                        Think & Learn Privat...
# 10  \n                        Think & Learn Privat...
# 11  \n                        United Nations Volun...
# 12  \n                        Times Internet      ...
# 13  \n                        LIC Of India        ...
# 14  \n                        Bewakoof            ...
# 15  \n                        Aditya Birla Fashion...
# ...

# %%
df["APPLY_BY"]=a1

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0   \n                        Childo Education Res...
# 1   \n                        Jankalyan Multipurpo...
# 2   \n                        Pledge A Smile Found...
# 3   \n                        Tare Zameen Foundati...
# 4   \n                        Internshala         ...
# 5   \n                        Justdial Limited    ...
# 6   \n                        BYJU'S The Learning ...
# 7   \n                        HCL Technologies    ...
# 8   \n                        Taylor & Francis Ind...
# 9   \n                        Think & Learn Privat...
# 10  \n                        Think & Learn Privat...
# 11  \n                        United Nations Volun...
# 12  \n                        Times Internet      ...
# 13  \n                        LIC Of India        ...
# 14  \n                        Bewakoof            ...
# 15  \n                        Aditya Birla Fashion...
# ...

# %%
df["START_DATE"]=sd1

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0   \n                        Childo Education Res...
# 1   \n                        Jankalyan Multipurpo...
# 2   \n                        Pledge A Smile Found...
# 3   \n                        Tare Zameen Foundati...
# 4   \n                        Internshala         ...
# 5   \n                        Justdial Limited    ...
# 6   \n                        BYJU'S The Learning ...
# 7   \n                        HCL Technologies    ...
# 8   \n                        Taylor & Francis Ind...
# 9   \n                        Think & Learn Privat...
# 10  \n                        Think & Learn Privat...
# 11  \n                        United Nations Volun...
# 12  \n                        Times Internet      ...
# 13  \n                        LIC Of India        ...
# 14  \n                        Bewakoof            ...
# 15  \n                        Aditya Birla Fashion...
# ...

# %%
df.to_csv("Internship.csv")

# %%
df["COMPANY_NAME"]=df["COMPANY_NAME"].str.strip("\n")

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0                           Childo Education Resea...
# 1                           Jankalyan Multipurpose...
# 2                           Pledge A Smile Foundat...
# 3                           Tare Zameen Foundation...
# 4                           Internshala           ...
# 5                           Justdial Limited      ...
# 6                           BYJU'S The Learning Ap...
# 7                           HCL Technologies      ...
# 8                           Taylor & Francis India...
# 9                           Think & Learn Private ...
# 10                          Think & Learn Private ...
# 11                          United Nations Volunte...
# 12                          Times Internet        ...
# 13                          LIC Of India          ...
# 14                          Bewakoof              ...
# 15                          Aditya Birla Fashion &...
# ...

# %%
df["DURATION_IN_MONTHS"]=df["DURATION_IN_MONTHS"].str.strip("\n")

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0                           Childo Education Resea...
# 1                           Jankalyan Multipurpose...
# 2                           Pledge A Smile Foundat...
# 3                           Tare Zameen Foundation...
# 4                           Internshala           ...
# 5                           Justdial Limited      ...
# 6                           BYJU'S The Learning Ap...
# 7                           HCL Technologies      ...
# 8                           Taylor & Francis India...
# 9                           Think & Learn Private ...
# 10                          Think & Learn Private ...
# 11                          United Nations Volunte...
# 12                          Times Internet        ...
# 13                          LIC Of India          ...
# 14                          Bewakoof              ...
# 15                          Aditya Birla Fashion &...
# ...

# %%
df["DURATION_IN_MONTHS"]=df["DURATION_IN_MONTHS"].str.strip(" Months")

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0                           Childo Education Resea...
# 1                           Jankalyan Multipurpose...
# 2                           Pledge A Smile Foundat...
# 3                           Tare Zameen Foundation...
# 4                           Internshala           ...
# 5                           Justdial Limited      ...
# 6                           BYJU'S The Learning Ap...
# 7                           HCL Technologies      ...
# 8                           Taylor & Francis India...
# 9                           Think & Learn Private ...
# 10                          Think & Learn Private ...
# 11                          United Nations Volunte...
# 12                          Times Internet        ...
# 13                          LIC Of India          ...
# 14                          Bewakoof              ...
# 15                          Aditya Birla Fashion &...
# ...

# %%
df["STIPEND_PER_MONTH"]=df["STIPEND_PER_MONTH"].str.strip("/month")

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0                           Childo Education Resea...
# 1                           Jankalyan Multipurpose...
# 2                           Pledge A Smile Foundat...
# 3                           Tare Zameen Foundation...
# 4                           Internshala           ...
# 5                           Justdial Limited      ...
# 6                           BYJU'S The Learning Ap...
# 7                           HCL Technologies      ...
# 8                           Taylor & Francis India...
# 9                           Think & Learn Private ...
# 10                          Think & Learn Private ...
# 11                          United Nations Volunte...
# 12                          Times Internet        ...
# 13                          LIC Of India          ...
# 14                          Bewakoof              ...
# 15                          Aditya Birla Fashion &...
# ...

# %%
df["DURATION_IN_MONTHS"]=df["DURATION_IN_MONTHS"].str.strip("/Week")

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0                           Childo Education Resea...
# 1                           Jankalyan Multipurpose...
# 2                           Pledge A Smile Foundat...
# 3                           Tare Zameen Foundation...
# 4                           Internshala           ...
# 5                           Justdial Limited      ...
# 6                           BYJU'S The Learning Ap...
# 7                           HCL Technologies      ...
# 8                           Taylor & Francis India...
# 9                           Think & Learn Private ...
# 10                          Think & Learn Private ...
# 11                          United Nations Volunte...
# 12                          Times Internet        ...
# 13                          LIC Of India          ...
# 14                          Bewakoof              ...
# 15                          Aditya Birla Fashion &...
# ...

# %%
df["APPLY_BY"]=df["APPLY_BY"].str.strip(" '")

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0                           Childo Education Resea...
# 1                           Jankalyan Multipurpose...
# 2                           Pledge A Smile Foundat...
# 3                           Tare Zameen Foundation...
# 4                           Internshala           ...
# 5                           Justdial Limited      ...
# 6                           BYJU'S The Learning Ap...
# 7                           HCL Technologies      ...
# 8                           Taylor & Francis India...
# 9                           Think & Learn Private ...
# 10                          Think & Learn Private ...
# 11                          United Nations Volunte...
# 12                          Times Internet        ...
# 13                          LIC Of India          ...
# 14                          Bewakoof              ...
# 15                          Aditya Birla Fashion &...
# ...

# %%
df["STIPEND_PER_MONTH"]=df["STIPEND_PER_MONTH"].str.strip(" /month + Incentives")

# %%
df
# Out:
#                                          COMPANY_NAME  \
# 0                           Childo Education Resea...
# 1                           Jankalyan Multipurpose...
# 2                           Pledge A Smile Foundat...
# 3                           Tare Zameen Foundation...
# 4                           Internshala           ...
# 5                           Justdial Limited      ...
# 6                           BYJU'S The Learning Ap...
# 7                           HCL Technologies      ...
# 8                           Taylor & Francis India...
# 9                           Think & Learn Private ...
# 10                          Think & Learn Private ...
# 11                          United Nations Volunte...
# 12                          Times Internet        ...
# 13                          LIC Of India          ...
# 14                          Bewakoof              ...
# 15                          Aditya Birla Fashion &...
# ...

# %%
df.to_csv("Internship WEBSCRAPPER.csv")
